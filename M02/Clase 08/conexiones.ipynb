# %%
import psycopg2
import pymysql
from sqlalchemy import create_engine
import pandas as pd

# %%
conexion = pymysql.connect(
    host='localhost',                      # Servidor donde esta alojada mi base de datos
    database='henry',                  # Nombre de la base de datos
    user='root',                      # Usuario con el cual me voy a conectar
    password='root1234'                   # Contraseña del usuario
)

cursor = conexion.cursor()

# %%
cursor.execute('SELECT * FROM alumno;')
# Out:
# 180

# %%
for elemento in cursor:
    print(elemento)

# %%
cursor.execute('CREATE DATABASE henry_2;')
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 cursor.execute('CREATE DATABASE henry_2;')
#
# File c:\Python\Lib\site-packages\pymysql\cursors.py:158, in Cursor.execute(self, query, args)
#     154     pass
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#     160 return result
#
# File c:\Python\Lib\site-packages\pymysql\cursors.py:325, in Cursor._query(self, q)
#     323 conn = self._get_db()
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#     327 return self.rowcount
#
# File c:\Python\Lib\site-packages\pymysql\connections.py:548, in Connection.query(self, sql, unbuffered)
#     546 if isinstance(sql, str):
#     547     sql = sql.encode(self.encoding, "surrogateescape")
# --> 548 self._execute_command(COMMAND.COM_QUERY, sql)
# ...

# %%
cursor.execute('USE henry_2;')
cursor.execute('CREATE TABLE colesterol (nombre VARCHAR(30), Edad INT, Sexo VARCHAR(2), Peso FLOAT, Altura FLOAT, Colesterol FLOAT);')
# Out:
# 0

# %%
conexion.close()

# %%
psycopg2.connect(
    database='henry',
    host='localhost',
    user='root',
    password='root1234'
)

# %%
# SQLAlchemy

df = pd.read_csv('colesterol.csv',sep=';')
df
# Out:
#                              nombre  edad sexo   peso altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0   1,79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0   1,73       232.0
# 2             Javier García Sánchez    24    H    NaN   1,81       191.0
# 3               Carmen López Pinzón    35    M   65.0   1,70       200.0
# 4              Marisa López Collado    46    M   51.0   1,58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0   1,74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0   1,72       276.0
# 7             Pilar Martín González    22    M   60.0   1,66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0   1,94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0   1,85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0   1,62       262.0
# 11       José María de la Guía Sanz    58    H   78.0   1,87       198.0
# ...

# %%
# PATH -> 'motorsql+motorpython://USER:PASSWORD@HOST:PORT/DATABASE'
# AWS tiene el motor RDS para crear bases SQL, HOST = URL
my_con = create_engine('mysql+pymysql://root:root1234@localhost:3306/henry_2')
if my_con:
    print('Conexion exitosa!')
# Out:
# Conexion exitosa!

# %%
if my_con:
    print('Conexion exitosa!')
# Out:
# Conexion exitosa!

# %%
df.to_sql(con=my_con,if_exists='replace',name='colesterol',index=False)
# Out:
# 14

# %%
conexion = pymysql.connect(
    host='localhost',                      # Servidor donde esta alojada mi base de datos
    database='henry',                  # Nombre de la base de datos
    user='root',                      # Usuario con el cual me voy a conectar
    password='root1234'                   # Contraseña del usuario
)

cursor = conexion.cursor()

# %%
cursor.execute('USE henry_2;')
cursor.execute('SELECT * FROM colesterol;')
# Out:
# 14

# %%
for elemento in cursor:
    print(elemento)
# Out:
# ('José Luis Martínez Izquierdo', 18, 'H', 85.0, '1,79', 182.0)
# ('Rosa Díaz Díaz', 32, 'M', 65.0, '1,73', 232.0)
# ('Javier García Sánchez', 24, 'H', None, '1,81', 191.0)
# ('Carmen López Pinzón', 35, 'M', 65.0, '1,70', 200.0)
# ('Marisa López Collado', 46, 'M', 51.0, '1,58', 148.0)
# ('Antonio Ruiz Cruz', 68, 'H', 66.0, '1,74', 249.0)
# ('Antonio Fernández Ocaña', 51, 'H', 62.0, '1,72', 276.0)
# ('Pilar Martín González', 22, 'M', 60.0, '1,66', None)
# ('Pedro Gálvez Tenorio', 35, 'H', 90.0, '1,94', 241.0)
# ('Santiago Reillo Manzano', 46, 'H', 75.0, '1,85', 280.0)
# ('Macarena Álvarez Luna', 53, 'M', 55.0, '1,62', 262.0)
# ('José María de la Guía Sanz', 58, 'H', 78.0, '1,87', 198.0)
# ('Miguel Angel Cuadrado Gutiérrez', 27, 'H', 109.0, '1,98', 210.0)
# ('Carolina Rubio Moreno', 20, 'M', 61.0, '1,77', 194.0)

# %%
# Create engine lo que hace es crear la conexion, no hacer querys
my_conn = create_engine('mysql+pymysql://root:root1234@localhost:3306/henry')

# %%
df2 = pd.read_sql(sql='SELECT * FROM alumno;', con=my_conn)
df2
# Out:
#      IdAlumno CedulaIdentidad   Nombre    Apellido FechaNacimiento  \
# 0           1       274352477  Candice       Rojas      2000-12-10
# 1           2       313262855  Beverly     Gardner      2006-10-03
# 2           3       335199030   Carlos       Frank      2006-07-11
# 3           4       171722128   Callum   Velazquez      2005-11-18
# 4           5       14374907K    Kelly  Strickland      2005-11-26
# ..        ...             ...      ...         ...             ...
# 175       176       335187784     Mara     Rodgers      2004-03-29
# 176       177       122874648   Galvin       Jones      2005-11-08
# 177       178       386395705   Tashya      Clarke      1992-07-02
# 178       179       402918667    Imani        Mack      2000-07-28
# 179       180       277347865  William        Long      2009-12-06
#
#     FechaIngreso  IdCohorte
# 0     2020-01-21       1235
# 1     2019-12-04       1235
# 2     2019-12-13       1235
# 3     2019-12-17       1235
# ...

# %%
# Esto es por seguridad
conexion.close()

# %%
# SQLAlchemy FUNCIONA PARA CUALQUIER MOTOR, NO SOLO MYSQL

"con_postgres = create_engine('postgresql://admin:pass@localhost:5432/productDb')"

# %%
df3 = pd.read_csv('https://cdn.buenosaires.gob.ar/datosabiertos/datasets/ente-de-turismo/oferta-establecimientos-gastronomicos/oferta_gastronomica.csv')

# %%
df3
# Out:
#            long        lat    id            nombre    categoria  \
# 0    -58.363307 -34.622963  1602      GUANTANAMERA  RESTAURANTE
# 1    -58.392330 -34.621554   676   1843 VINACOTECA      VINERIA
# 2    -58.453542 -34.560311   487      2080 EXPRESS  RESTAURANTE
# 3    -58.475491 -34.677051  2737                22         CAFE
# 4    -58.425437 -34.585695     2          4 EN 2 I  RESTAURANTE
# ...         ...        ...   ...               ...          ...
# 2818 -58.401107 -34.599643   893  ZOE PIZZA & CAFE  RESTAURANTE
# 2819 -58.386372 -34.607178  2546             ZOMBI  RESTAURANTE
# 2820 -58.463108 -34.543369  1521              ZONA  RESTAURANTE
# 2821 -58.395697 -34.602213   894           ZOO BAR  RESTAURANTE
# 2822 -58.439863 -34.600868  2854          Angelito          BAR
#
#              cocina          ambientacion   telefono               mail  \
# 0            CUBANA               MODERNO  4314 0770                NaN
# ...

# %%
import matplotlib.pyplot as plt
from scipy import stats
