# %%
import pandas as pd

# Load the Excel file
file_path = r'BBDD_Hospitalización.xlsx'
hospitalization_data = pd.read_excel(file_path)

# Display the first few rows of the dataframe
hospitalization_data.head()
# Out:
# c:\Python\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    EDAD DIABETES HOSPITALIZACIÓN ULTIMO MES   PSA BIOPSIAS PREVIAS  \
# 0  53.0       NO                         NO   4.0               NO
# 1  56.0       NO                         NO   7.7               NO
# 2  57.0       NO                         NO  29.0               SI
# 3  56.0       NO                         NO   7.0               NO
# 4  55.0       NO                         NO  29.0               SI
#
#   VOLUMEN PROSTATICO ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS  \
# 0                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 1                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 2                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 3                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
# 4                 SI          FLUOROQUINOLONA_AMINOGLICOSIDO
#
# ...

# %%
descriptive_statistics = hospitalization_data.describe()

descriptive_statistics
# Out:
#              EDAD         PSA  NUMERO DE MUESTRAS TOMADAS  \
# count  568.000000  564.000000                  568.000000
# mean    63.882042   13.271401                   12.996479
# std      9.281517   15.668966                    3.921180
# min     39.000000    0.600000                    4.000000
# 25%     59.000000    5.600000                   12.000000
# 50%     64.000000    8.000000                   12.000000
# 75%     69.000000   15.000000                   12.000000
# max    151.000000  100.000000                   24.000000
#
#        DIAS HOSPITALIZACION MQ  DIAS HOSPITALIZACIÓN UPC
# count               568.000000                568.000000
# mean                  0.165493                  0.014085
# std                   0.958066                  0.196474
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# ...

# %%
# Categorical Data Analysis: Frequency distribution of key categorical variables
categorical_columns = hospitalization_data.select_dtypes(include=['object']).columns

categorical_data_frequencies = {col: hospitalization_data[col].value_counts() for col in categorical_columns}

categorical_data_frequencies
# Out:
# {'DIABETES': DIABETES
#  NO    505
#  SI     63
#  Name: count, dtype: int64,
#  'HOSPITALIZACIÓN ULTIMO MES': HOSPITALIZACIÓN ULTIMO MES
#  NO    563
#  SI      5
#  Name: count, dtype: int64,
#  'BIOPSIAS PREVIAS': BIOPSIAS PREVIAS
#  NO    510
#  SI     56
#  Name: count, dtype: int64,
#  'VOLUMEN PROSTATICO': VOLUMEN PROSTATICO
#  SI    408
#  NO    159
#  Name: count, dtype: int64,
#  'ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS': ANTIBIOTICO UTILIAZADO EN LA PROFILAXIS
#  FLUOROQUINOLONA_AMINOGLICOSIDO    448
#  CEFALOSPORINA_AMINOGLUCOCIDO       56
#  OTROS                              42
#  OROQUINOLONAS                      18
#  FLUOROQUINOLONA_AMINOGLICÓSIDO      4
#  Name: count, dtype: int64,
#  'CUP': CUP
#  NO    563
#  SI      4
#  Name: count, dtype: int64,
#  'ENF. CRONICA PULMONAR OBSTRUCTIVA': ENF. CRONICA PULMONAR OBSTRUCTIVA
#  NO          546
#  SI           12
#  SI, EPOC      4
#  SI, ASMA      4
#  Name: count, dtype: int64,
#  'BIOPSIA': BIOPSIA
# ...
